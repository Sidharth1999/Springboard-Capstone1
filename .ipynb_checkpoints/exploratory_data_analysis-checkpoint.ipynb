# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./data/WrangledCollegeScorecard.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7804 entries, 0 to 7803
# Columns: 223 entries, Unnamed: 0 to NOTFIRSTGEN_RPY_3YR_RT_SUPP
# dtypes: float64(212), int64(10), object(1)
# memory usage: 13.3+ MB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'UNITID', 'OPEID', 'opeid6', 'INSTURL', 'HCM2', 'main',
#        'NUMBRANCH', 'CONTROL', 'st_fips',
#        ...
#        'LO_INC_RPY_3YR_RT_SUPP', 'MD_INC_RPY_3YR_RT_SUPP',
#        'HI_INC_RPY_3YR_RT_SUPP', 'DEP_RPY_3YR_RT_SUPP', 'PELL_RPY_3YR_RT_SUPP',
#        'NOPELL_RPY_3YR_RT_SUPP', 'FEMALE_RPY_3YR_RT_SUPP',
#        'MALE_RPY_3YR_RT_SUPP', 'FIRSTGEN_RPY_3YR_RT_SUPP',
#        'NOTFIRSTGEN_RPY_3YR_RT_SUPP'],
#       dtype='object', length=223)

# %%
#Features to explore - 
# region
# Public/PrivateNonprofit/Private For-Profit (CONTROL)
# Admission rate (ADM_RATE_ALL)
# Cost of attendance (COSTT4_P)
# Undergraduate students by family income (INC_PCT_[LO/M1/M2/H1/H2])
# 25 and above students (UG25abv)
# Percentage of federal loan (PCTFLOAN)
# First gen students (PAR_ED_PCT_[1STGEN/MS/HS/PS])
# DEBT_MDN, GRAD_DEBT_MDN, WDRAW_DEBT_MDN,PELL_DEBT_MDN,NOPELL_DEBT_MDN,FEMALE_DEBT_MDN,MALE_DEBT_MDN,FIRSTGEN_DEBT_MDN,NOTFIRSTGEN_DEBT_MDN,
# DEBT_N, GRAD_DEBT_N, WDRAW_DEBT_N,PELL_DEBT_N,NOPELL_DEBT_N,FEMALE_DEBT_N,MALE_DEBT_N,FIRSTGEN_DEBT_N,NOTFIRSTGEN_DEBT_N,
#Percentage of degrees awarded in each two-digit CIP field of study (PCIP[01-54])
#Fraction of borrowers at institution making repayment progress after x years leaving the school (RPY_xYR_RT)


#Classification variables:
#CONTROL, HBCU/ANNHI/PBI/AANAPII/NANTI/HSI/MENONLY/WOMENONLY/TRIBAL,

# %%
string_cols = df.select_dtypes('object')
string_cols.columns
# Out:
# Index(['INSTURL'], dtype='object')

# %%
import math
def discretize_column_into_intervals(df, column, intervals):
    interval_size = math.ceil((df[column].max() - df[column].min()+1)/intervals)
    bins = list(range(df[column].min()-1, df[column].max()+interval_size, interval_size))
    labels = [f'{column}_bin_{i}' for i in range(len(bins)-1)]
    return pd.cut(df[column], bins, labels=labels, include_lowest=True)

def discretize_column_into_qtiles(df, column, qtiles):
    labels = [f'{column}_qtile_{i}' for i in range(qtiles)]
    return pd.qcut(df[column], qtiles, labels=labels)

# %%
sns.scatterplot(x='UG25abv', y='DEBT_MDN', hue='CONTROL', data=df)
# Out:
# <AxesSubplot:xlabel='UG25abv', ylabel='DEBT_MDN'>

# %%
#There is an annoying outlier. Let's drop it
df = df[df['DEBT_MDN'] != df['DEBT_MDN'].max()]

# %%
sns.scatterplot(x='UG25abv', y='DEBT_MDN', hue='CONTROL', data=df)
# Out:
# <AxesSubplot:xlabel='UG25abv', ylabel='DEBT_MDN'>

# %%
sns.scatterplot(x='UG25abv', y='PCTFLOAN', hue='CONTROL', data=df, palette=sns.color_palette('tab10', as_cmap=True))
# Out:
# <AxesSubplot:xlabel='UG25abv', ylabel='PCTFLOAN'>

# %%
sns.scatterplot(x='UG25abv', y='PCTFLOAN', hue='CONTROL', data=df, palette=sns.color_palette('tab10', as_cmap=True))
# Out:
# <AxesSubplot:xlabel='UG25abv', ylabel='PCTFLOAN'>

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 60]

fig, axs = plt.subplots(20, 1)
regression_features = ['ADM_RATE_ALL', 'COSTT4_P', 'UG25abv', 'PCTFLOAN', 'DEBT_MDN']
classification_features = ['region', 'CONTROL', 'MENONLY', 'WOMENONLY', 'HBCU']
plot_num = 0

for i in range(len(regression_features)-1):
    for j in range(i+1, len(regression_features)):
        for classification_feature in classification_features:
            sns.scatterplot(x=regression_features[i], y=regression_features[j], hue=classification_feature, data=df, '''palette=sns.color_palette('tab10', as_cmap=True),''' ax=axs[plot_num])
            plot_num += 1
